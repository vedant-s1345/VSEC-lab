# %%
import requests
import pandas as pd

# Step 1: Identify the API and endpoint
api_url = 'https://api.coingecko.com/api/v3/coins/markets'

#api_url = 'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=39.099724&lon=-94.578331&dt=1643803200&appid={3ee92f6cff135cc54976b8136a19cf18}'
#api_url = 'https://rapidapi.com/blaazetech/api/indian-stock-exchange'
'''parameters = {
    'vs_currency': 'usd',   # Convert data to USD
    'order': 'market_cap_desc',  # Order by market cap
    'per_page': 10,  # Limit the results to 10 cryptocurrencies
    'page': 1,  # Get data from the first page
    'sparkline': False  # Do not include sparkline data
}'''

# Step 2: Fetch data from the CoinGecko API
response = requests.get(api_url, params=parameters)

# Step 3: Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Get the data in JSON format

    # Step 4: Convert JSON data to a DataFrame
    df = pd.DataFrame(data)

    # Step 5: Display the first few rows of the DataFrame
    print(df.head())
else:
    print(f"Error: Unable to fetch data (Status code: {response.status_code})")
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       solana    sol    Solana
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...       60262.00
# 1  https://coin-images.coingecko.com/coins/images...        2321.25
# 2  https://coin-images.coingecko.com/coins/images...           1.00
# 3  https://coin-images.coingecko.com/coins/images...         545.13
# 4  https://coin-images.coingecko.com/coins/images...         131.10
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1190600035584                1            1265594462662   40420407795
# 1   279360227019                2             279360227019   15055818273
# 2   118740422257                3             118740422257   52107332783
# 3    79530191537                4              79530191537     779698575
# 4    61404769178                5              76664489105    2240515783
#
#     high_24h  ...  total_supply   max_supply       ath  ath_change_percentage  \
# 0  61243.000  ...  2.100000e+07   21000000.0  73738.00              -18.26137
# 1   2389.290  ...  1.203433e+08          NaN   4878.26              -52.46709
# 2      1.005  ...  1.187011e+11          NaN      1.32              -24.46412
# 3    552.860  ...  1.458876e+08  200000000.0    717.48              -23.99988
# 4    135.480  ...  5.847646e+08          NaN    259.96              -49.59334
#
#                    ath_date        atl  atl_change_percentage  \
# 0  2024-03-14T07:10:36.635Z  67.810000           8.878551e+04
# 1  2021-11-10T14:24:19.604Z   0.432979           5.354410e+05
# 2  2018-07-24T00:00:00.000Z   0.572521           7.456332e+01
# 3  2024-06-06T14:10:59.816Z   0.039818           1.369347e+06
# 4  2021-11-06T21:54:35.825Z   0.500801           2.606543e+04
#
#                    atl_date  \
# 0  2013-07-06T00:00:00.000Z
# 1  2015-10-20T00:00:00.000Z
# 2  2015-03-02T00:00:00.000Z
# 3  2017-10-19T00:00:00.000Z
# 4  2020-05-11T19:35:23.449Z
#
#                                                  roi              last_updated
# 0                                               None  2024-09-18T05:59:11.756Z
# 1  {'times': 50.50243601415782, 'currency': 'btc'...  2024-09-18T05:59:12.993Z
# 2                                               None  2024-09-18T05:59:16.568Z
# 3                                               None  2024-09-18T05:59:13.768Z
# 4                                               None  2024-09-18T05:59:16.096Z
#
# [5 rows x 26 columns]

# %%
import requests
import pandas as pd

# Step 1: Define the API endpoint and parameters
api_url = 'https://api.weatherstack.com/current'

params = {
    'access_key': 'c85e487e0e9f0d5b29c61e55979e753d',  # Replace with your actual API key
    'query': 'Delhi'
}

# Step 2: Fetch data from the Weatherstack API
response = requests.get(api_url, params=params)


# Step 3: Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Get the data in JSON format

    # Step 4: Convert JSON data to a DataFrame
    # Print the raw data to understand its structure
    print(data)  # Helps to understand how to construct DataFrame

    # Example of converting to DataFrame (adjust as necessary)
    # Extracting relevant data from 'current'
    current_weather = data.get('current', {})
    df = pd.DataFrame([current_weather])
    
    # Step 5: Display the first few rows of the DataFrame
    print(df.head())
else:
    print(f"Error: Unable to fetch data (Status code: {response.status_code})")
    print(response.text)  # Print the error message if available
# Out:
# {'request': {'type': 'City', 'query': 'Delhi, Canada', 'language': 'en', 'unit': 'm'}, 'location': {'name': 'Delhi', 'country': 'Canada', 'region': 'Ontario', 'lat': '42.850', 'lon': '-80.500', 'timezone_id': 'America/Toronto', 'localtime': '2024-09-18 04:21', 'localtime_epoch': 1726633260, 'utc_offset': '-4.0'}, 'current': {'observation_time': '08:21 AM', 'temperature': 13, 'weather_code': 113, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'], 'weather_descriptions': ['Clear'], 'wind_speed': 5, 'wind_degree': 129, 'wind_dir': 'SE', 'pressure': 1018, 'precip': 0, 'humidity': 98, 'cloudcover': 0, 'feelslike': 13, 'uv_index': 1, 'visibility': 10, 'is_day': 'no'}}
#   observation_time  temperature  weather_code  \
# 0         08:21 AM           13           113
#
#                                        weather_icons weather_descriptions  \
# 0  [https://cdn.worldweatheronline.com/images/wsy...              [Clear]
#
#    wind_speed  wind_degree wind_dir  pressure  precip  humidity  cloudcover  \
# 0           5          129       SE      1018       0        98           0
#
#    feelslike  uv_index  visibility is_day
# 0         13         1          10     no
