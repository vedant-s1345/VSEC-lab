# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.array([1,2,6,8])
y1=np.array([3,8,1,10])
x2=np.array(["a","b","c"])
y2=np.array([1,5,7])

#plt.plot(x1,y1,ls="--",linewidth=10,color='black',marker="o",ms=20,mec="y",mfc="r")
#plt.title("fuckkkkkkk oofffffff",loc="left")
#plt.xlabel("aaaaaaaaaaaaa")#lable for x axis
#plt.ylabel("yyyyyyyyyyyy")#lable for y axis
#marker=marks the point,
#ms=marker size
#mec=marker edge color
#mfc=marker fill color
#linestyle/ls="dotted"(eg:- '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted')
#linewidth=width of line
#plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
#plt.bar(x2,y2,color="red")
#plt.bar(x2,y2,width=0.1)
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import pandas as pd
std=[(1,'ved',19),(2,'ant',20),(3,'sar',21),(4,'ode',22),
     (5,'dog',5),(6,'cat',6),(7,'mmee',1),(8,'youu',1)]
print(std)
# Out:
# [(1, 'ved', 19), (2, 'ant', 20), (3, 'sar', 21), (4, 'ode', 22), (5, 'dog', 5), (6, 'cat', 6), (7, 'mmee', 1), (8, 'youu', 1)]

# %%
df=pd.DataFrame(std,columns=['no.','name','age'])
print(df)
# Out:
#    no.  name  age
# 0    1   ved   19
# 1    2   ant   20
# 2    3   sar   21
# 3    4   ode   22
# 4    5   dog    5
# 5    6   cat    6
# 6    7  mmee    1
# 7    8  youu    1

# %%
import pandas as pd
data=pd.read_csv("C:/Users/Pccoe/Desktop/123B1F129/Elephantpopulation1993to2017.csv")
print(df)
# Out:
#                    STATE ELEPHANT POPULATION IN 1997  \
# 0      Arunachal Pradesh                        1800
# 1                  Assam                        5312
# 2              Meghalaya                        1840
# 3               Nagaland                         158
# 4                Mizoram                          22
# 5                Manipur                          30
# 6                Tripura                          70
# 7    West Bengal (North)                         250
# 8    West Bengal (South)                          26
# 9              Jharkhand                         618
# 10                Odisha                        1800
# 11          Chhattisgarh        Census not conducted
# 12                Bihar         Census not conducted
# 13        Madhya Pradesh        Census not conducted
# 14          Uttarakhand                         1130
# 15         Uttar Pradesh                          70
# 16               Haryana        Census not conducted
# ...

# %%
data.head()
# Out:
#                STATE ELEPHANT POPULATION IN 1993 ELEPHANT POPULATION IN 1997  \
# 0  Arunachal Pradesh                        2102                        1800
# 1              Assam                        5524                        5312
# 2          Meghalaya                        2872                        1840
# 3           Nagaland                         178                         158
# 4            Mizoram                          15                          22
#
#   ELEPHANT POPULATION IN 2002 ELEPHANT POPULATION IN 2007  \
# 0                        1607                        1690
# 1                        5246                        5281
# 2                        1868                        1811
# 3                         145                         152
# 4                          33                          12
#
#     ELEPHANT POPULATION IN 2012  ELEPHANT POPULATION IN 2017
# 0                           890                         1614
# ...

# %%
#df.shape
data.size
# Out:
# 175

# %%
data.loc[[1,10,20]]
# Out:
#      STATE ELEPHANT POPULATION IN 1993 ELEPHANT POPULATION IN 1997  \
# 1    Assam                        5524                        5312
# 10  Odisha                        1750                        1800
# 20  Kerala                        3500                        3600
#
#    ELEPHANT POPULATION IN 2002 ELEPHANT POPULATION IN 2007  \
# 1                         5246                        5281
# 10                        1841                        1862
# 20                        3850                        6068
#
#    ELEPHANT POPULATION IN 2012  ELEPHANT POPULATION IN 2017
# 1                         5620                         5719
# 10                        1930                         1976
# 20                   5942-6422                         5706

# %%
data.iloc[[1,10,20]]
# Out:
#    ELEPHANT POPULATION IN 1997 ELEPHANT POPULATION IN 2002  \
# 1                         5312                        5246
# 10                        1800                        1841
# 20                        3600                        3850
#
#    ELEPHANT POPULATION IN 2007 ELEPHANT POPULATION IN 2012  \
# 1                         5281                        5620
# 10                        1862                        1930
# 20                        6068                   5942-6422
#
#     ELEPHANT POPULATION IN 2017
# 1                          5719
# 10                         1976
# 20                         5706

# %%
data.head()
# Out:
#   ELEPHANT POPULATION IN 1997 ELEPHANT POPULATION IN 2002  \
# 0                        1800                        1607
# 1                        5312                        5246
# 2                        1840                        1868
# 3                         158                         145
# 4                          22                          33
#
#   ELEPHANT POPULATION IN 2007   ELEPHANT POPULATION IN 2012  \
# 0                        1690                           890
# 1                        5281                          5620
# 2                        1811  1811 (Census  not conducted)
# 3                         152                           212
# 4                          12          Census not conducted
#
#    ELEPHANT POPULATION IN 2017
# 0                         1614
# 1                         5719
# 2                         1754
# 3                          446
# 4                            7

# %%
data=df.drop['ELEPHANT POPULATION IN 2002']
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 data=df.drop['ELEPHANT POPULATION IN 2002']
#       2 print(data)
#
# TypeError: 'method' object is not subscriptable
